# %% [markdown]
# <a href="https://colab.research.google.com/github/nebjj/LeetCode-Working-Out/blob/main/TwoSum_Hashmap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = [2,7,11,15]
target = 13

# %%
def two_sum(numbers, target):
  hashmap = {}
  for index, number in enumerate(nums):
    complement = target - number
    if complement in hashmap:
      print(hashmap[complement], index)
    else:
      hashmap[number] = index

# %%
two_sum(nums, target = 13)
# Out:
# 0 2

# %%
two_sum(nums, target = 9)
# Out:
# 0 1

# %%
two_sum(nums, target = 22)
# Out:
# 1 3

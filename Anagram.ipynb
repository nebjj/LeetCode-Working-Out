# %% [markdown]
# <a href="https://colab.research.google.com/github/nebjj/LeetCode-Working-Out/blob/main/Anagram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter
def isAnagram(s: str, t: str) -> bool:
    return Counter(s) == Counter(t) #runtime 4-7ms

'''
if len(s) != len(t):
    return False

count_dict = {}

for character in s:
    if character in count_dict:
        count_dict[character] += 1
    else:
        count_dict[character] = 1

for character in t:
    if character not in count_dict:
        return False
    else:
        count_dict[character] -= 1

        if count_dict[character] < 0:
            return False

return True
'''  #runtime 14ms

'''
if len(s) != len(t):
  return False
'''
# Out:
# '\nif len(s) != len(t):\n  return False\n'

# %%
isAnagram(s="naga",t="agan")
# Out:
# True

# %%
isAnagram(s="cat",t="car")
# Out:
# False
